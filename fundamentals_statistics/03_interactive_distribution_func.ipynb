# %% [markdown]
# # 📘 Interactive Probability Distributions in Python

# %% [markdown]
# **Purpose:**
#
# This interactive notebook demonstrates how the parameters of different
# probability distributions affect their shapes using Python + ipywidgets.
#
# Topics Covered:
# 1. Random Variables (Discrete & Continuous)
# 2. Probability Distributions:
#     - Bernoulli
#     - Binomial
#     - Poisson
#     - Normal
#     - Uniform
#     - Exponential
#     - Gamma
# 3. Interactive sliders to visualize parameter effects.

# %% [markdown]
# > **NOTE:** You will require following python libarires:
#
# > numpy matplotlib seaborn scipy ipywidgets
#
# > If not allready installed, use following commands:
#
# > pip install numpy matplotlib seaborn scipy ipywidgets

# %%
# ------------------------------------------------------------
# 🔹 Import Required Libraries
# ------------------------------------------------------------
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import bernoulli, binom, poisson, norm, uniform, expon, gamma
from ipywidgets import interact, FloatSlider, IntSlider

sns.set(style="whitegrid", font_scale=1.1)
plt.rcParams["figure.figsize"] = (8, 5)

# %% [markdown]
# ### 🧩 1️⃣ Bernoulli Distribution (Interactive)

# %%
# ------------------------------------------------------------
# 🎯 Bernoulli Distribution - Interactive
# ------------------------------------------------------------
"""
Displays the probability of success (1) and failure (0) for different 'p'.
"""

@interact(p=FloatSlider(value=0.5, min=0.0, max=1.0, step=0.05, description="p (success)"))
def plot_bernoulli(p):
    x = [0, 1]
    y = bernoulli.pmf(x, p)
    plt.stem(x, y, basefmt=" ", use_line_collection=True)
    plt.title(f"Bernoulli Distribution (p={p:.2f})")
    plt.xlabel("x")
    plt.ylabel("P(X=x)")
    plt.ylim(0, 1)
    plt.show()

# %% [markdown]
# ### 🧩 2️⃣ Binomial Distribution (Interactive)

# %%
# ------------------------------------------------------------
# 🎯 Binomial Distribution - Interactive
# ------------------------------------------------------------
"""
Visualizes how the probability of successes changes as we vary 'n' and 'p'.
"""

@interact(
    n=IntSlider(value=10, min=1, max=50, step=1, description="n (trials)"),
    p=FloatSlider(value=0.5, min=0.0, max=1.0, step=0.05, description="p (success)"),
)
def plot_binomial(n, p):
    x = np.arange(0, n + 1)
    y = binom.pmf(x, n, p)
    plt.plot(x, y, "o-", color="teal")
    plt.title(f"Binomial Distribution (n={n}, p={p:.2f})")
    plt.xlabel("x (Successes)")
    plt.ylabel("P(X=x)")
    plt.show()

# %% [markdown]
# ### 🧩 3️⃣ Poisson Distribution (Interactive)

# %%
# ------------------------------------------------------------
# 🎯 Poisson Distribution - Interactive
# ------------------------------------------------------------
"""
Models the number of events in a fixed interval given average rate λ.
"""

@interact(lam=FloatSlider(value=4, min=0.5, max=15, step=0.5, description="λ (rate)"))
def plot_poisson(lam):
    x = np.arange(0, int(lam * 3) + 10)
    y = poisson.pmf(x, lam)
    plt.plot(x, y, "o-", color="purple")
    plt.title(f"Poisson Distribution (λ={lam:.2f})")
    plt.xlabel("x (events)")
    plt.ylabel("P(X=x)")
    plt.show()

# %% [markdown]
# ### 🌈 4️⃣ Normal Distribution (Interactive)

# %%
# ------------------------------------------------------------
# 🎯 Normal Distribution - Interactive
# ------------------------------------------------------------
"""
Shows how mean (μ) and standard deviation (σ) affect the normal curve.
"""

@interact(
    mu=FloatSlider(value=0, min=-5, max=5, step=0.5, description="μ (mean)"),
    sigma=FloatSlider(value=1, min=0.1, max=5, step=0.1, description="σ (std dev)"),
)
def plot_normal(mu, sigma):
    x = np.linspace(mu - 4*sigma, mu + 4*sigma, 1000)
    y = norm.pdf(x, mu, sigma)
    plt.plot(x, y, color="darkblue")
    plt.title(f"Normal Distribution (μ={mu:.2f}, σ={sigma:.2f})")
    plt.xlabel("x")
    plt.ylabel("f(x)")
    plt.show()

# %% [markdown]
# ### 🟩 5️⃣ Uniform Distribution (Interactive)

# %%
# ------------------------------------------------------------
# 🎯 Uniform Distribution - Interactive
# ------------------------------------------------------------
"""
Shows the effect of 'a' and 'b' on a uniform distribution.
"""

@interact(
    a=FloatSlider(value=0, min=-5, max=5, step=0.5, description="a (min)"),
    b=FloatSlider(value=5, min=0, max=10, step=0.5, description="b (max)"),
)
def plot_uniform(a, b):
    if a >= b:
        print("⚠️ Note: a must be less than b.")
        return
    x = np.linspace(a - 2, b + 2, 1000)
    y = uniform.pdf(x, loc=a, scale=b - a)
    plt.plot(x, y, color="green")
    plt.title(f"Uniform Distribution (a={a:.2f}, b={b:.2f})")
    plt.xlabel("x")
    plt.ylabel("f(x)")
    plt.show()

# %% [markdown]
# ### ⚡ 6️⃣ Exponential Distribution (Interactive)

# %%
# ------------------------------------------------------------
# 🎯 Exponential Distribution - Interactive
# ------------------------------------------------------------
"""
Shows how rate parameter λ (inverse of scale) affects the curve.
"""

@interact(lam=FloatSlider(value=1, min=0.1, max=5, step=0.1, description="λ (rate)"))
def plot_exponential(lam):
    x = np.linspace(0, 10, 1000)
    y = expon.pdf(x, scale=1/lam)
    plt.plot(x, y, color="orange")
    plt.title(f"Exponential Distribution (λ={lam:.2f})")
    plt.xlabel("x")
    plt.ylabel("f(x)")
    plt.show()

# %% [markdown]
# ### 🔷 7️⃣ Gamma Distribution (Interactive)

# %%
# ------------------------------------------------------------
# 🎯 Gamma Distribution - Interactive
# ------------------------------------------------------------
"""
Visualizes the Gamma distribution for different shape (k) and scale (θ) values.
"""

@interact(
    k=FloatSlider(value=2, min=0.5, max=10, step=0.5, description="k (shape)"),
    theta=FloatSlider(value=2, min=0.5, max=5, step=0.5, description="θ (scale)"),
)
def plot_gamma(k, theta):
    x = np.linspace(0, 40, 1000)
    y = gamma.pdf(x, a=k, scale=theta)
    plt.plot(x, y, color="crimson")
    plt.title(f"Gamma Distribution (k={k:.2f}, θ={theta:.2f})")
    plt.xlabel("x")
    plt.ylabel("f(x)")
    plt.show()

# %% [markdown]
# ## 🧠 Summary & Learning Notes
#
# ✅ This interactive notebook helps visualize key intuitions:
#
# 🔹 Discrete Distributions:
#    - Bernoulli (p): Success probability
#    - Binomial (n, p): Number of successes in trials
#    - Poisson (λ): Event frequency per interval
#
# 🔹 Continuous Distributions:
#    - Normal (μ, σ): Bell curve (center & spread)
#    - Uniform (a, b): Constant probability over interval
#    - Exponential (λ): Time until event
#    - Gamma (k, θ): Generalized waiting time
#
# 🎯 Parameter Insights:
#    - Increasing μ → shifts Normal curve right
#    - Increasing σ → flattens and widens the curve
#    - Increasing λ in Poisson/Exponential → sharper peak
#    - Gamma’s k and θ control skewness and spread
